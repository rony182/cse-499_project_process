# %%
import sqlite3
import pandas as pd
from bs4 import BeautifulSoup
from IPython.display import HTML, display, JSON

import unstructured_client
from unstructured_client import UnstructuredClient
from unstructured_client.models import operations, shared
from unstructured_client.models.errors import SDKError

from unstructured.partition.html import partition_html
from unstructured.staging.base import dict_to_elements, elements_to_json

import json
import os

import chromadb

# %%
# Connect to the SQLite database
conn = sqlite3.connect('investopedia_cleaned.db')

# Load all records into a pandas DataFrame
query = "SELECT processed_json FROM investopedia"
df_records = pd.read_sql_query(query, conn )

# Close the connection
conn.close()

# %%
# Count the number of records
num_records = len(df_records)
print(f"Number of records: {num_records}")
# Out:
# Number of records: 6288

# %%
# Connect to the SQLite database
conn = sqlite3.connect('investopedia_cleaned.db')

# Load all records into a pandas DataFrame
query = "SELECT processed_json FROM investopedia LIMIT 1"
df_record = pd.read_sql_query(query, conn )

# Close the connection
conn.close()

# %%
# Load the first record as a JSON object
record = json.loads(df_record['processed_json'][0])
record
# Out:
# [{'type': 'Title',
#   'element_id': '7ffe2592fb17a9276e7a6567c2458cd7',
#   'text': '0x (ZRX) Protocol: What It Meant and How It Worked',
#   'metadata': {'category_depth': 0,
#    'languages': ['eng'],
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': '1d6f144c0ca8b86aac2de00ae1523abe',
#   'text': 'Close',
#   'metadata': {'category_depth': 0,
#    'emphasized_text_contents': ['Close'],
#    'emphasized_text_tags': ['span'],
#    'languages': ['eng'],
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': 'd289e028f60bbbeb5cd3309880545e7c',
#   'text': 'What Was the 0x (ZRX) Protocol?',
#   'metadata': {'category_depth': 1,
#    'emphasized_text_contents': ['What Was the 0x (ZRX) Protocol?'],
#    'emphasized_text_tags': ['span'],
#    'languages': ['eng'],
#    'parent_id': '1d6f144c0ca8b86aac2de00ae1523abe',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': '9923862f4a4d5b34ef5900d1f96089fe',
#   'text': "The 0x (zero x) protocol enabled the peer-to-peer exchange of assets on the Ethereum blockchain. It was launched in 2017 by ZeroEx Labs, an organization based in San Francisco. The protocol itself was not, by the developer's definition, a decentralized exchange; it allowed for the creation of decentralized exchanges that can be used in broad applications.",
#   'metadata': {'languages': ['eng'],
#    'parent_id': 'd289e028f60bbbeb5cd3309880545e7c',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': '2f876c5500fb7fe7319d5deb69e138e3',
#   'text': 'However, the Commodities and Futures Trading Commission disagreed—it shut down the 0x protocol in September 2023 for operating as an unregistered exchange, and its developers were fined $200,000.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': 'd289e028f60bbbeb5cd3309880545e7c',
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': '1556b24ed8b29a93002b498629132fb5',
#   'text': 'Key Takeaways',
#   'metadata': {'category_depth': 2,
#    'languages': ['eng'],
#    'parent_id': 'd289e028f60bbbeb5cd3309880545e7c',
#    'filetype': 'text/html'}},
#  {'type': 'ListItem',
#   'element_id': 'd143962e0d66927f0fd56c9786c17266',
#   'text': 'The 0x protocol was an open protocol that enabled the peer-to-peer exchange of assets on the Ethereum blockchain.',
#   'metadata': {'category_depth': 1,
#    'languages': ['eng'],
#    'parent_id': '1556b24ed8b29a93002b498629132fb5',
#    'filetype': 'text/html'}},
#  {'type': 'ListItem',
#   'element_id': '82c103e6cfcd5ec4b7d200cce747a1cb',
#   'text': 'The 0x protocol was open source and managed by the 0x decentralized autonomous organization.',
#   'metadata': {'category_depth': 1,
#    'languages': ['eng'],
#    'parent_id': '1556b24ed8b29a93002b498629132fb5',
#    'filetype': 'text/html'}},
#  {'type': 'ListItem',
#   'element_id': 'b444a09d29db6b1724342a9967a9cff1',
#   'text': 'The 0z protocol was shut down, and as of June 26, 2024, it is no longer maintained.',
#   'metadata': {'category_depth': 1,
#    'languages': ['eng'],
#    'parent_id': '1556b24ed8b29a93002b498629132fb5',
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': '55dd585d792f2480a92bd7225d05492a',
#   'text': 'The History of 0x (ZRX) Protocol',
#   'metadata': {'category_depth': 1,
#    'emphasized_text_contents': ['The History of 0x (ZRX) Protocol'],
#    'emphasized_text_tags': ['span'],
#    'languages': ['eng'],
#    'parent_id': '1d6f144c0ca8b86aac2de00ae1523abe',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': '55cc60f9003e7fc25c2936ee68147039',
#   'text': '0x was founded by Will Warren and Amir Bandeali in 2017, who launched an initial coin offering in 2017. The ICO was a success, raising $24 million and another $85 million between two fundraising rounds between 2021 and 2022.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': '55dd585d792f2480a92bd7225d05492a',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': '8a322c40d430a22191f98071f722d5a4',
#   'text': 'The secondary protocol was created on Ethereum to act as a settlement layer for trading ERC 20 tokens. ERC 20 tokens are fungible (exchangeable) tokens that follow the standards set by Ethereum Request for Comment 20.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': '55dd585d792f2480a92bd7225d05492a',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': '710bc9a6458a8f57048642203c29d9d6',
#   'text': 'In 2021, 0x launched the 0x Decentralized Autonomous Organization (DAO), the organization that would allow participants to govern the progress of the project.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': '55dd585d792f2480a92bd7225d05492a',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': 'c2b5ef40702f0243386aed964c172118',
#   'text': 'But in September 2023, the Commodities and Futures Trading Commission filed and settled charges against ZeroEx, Inc, along with two other digital asset exchanges, Opyn, Inc, and Deridex. Charges included failing to register as a futures commission merchant, failing to register as a swap execution facility, and illegally offering leveraged and margined retail commodity transactions.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': '55dd585d792f2480a92bd7225d05492a',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': 'e97fea971227ed5da670330c9a275609',
#   'text': "ZeroEx was ordered to pay $200,000 in fines and cease operating as an exchange. As of June 26, 2024, the project community was very small, and the 0x Project's Reddit page had been abandoned.",
#   'metadata': {'languages': ['eng'],
#    'parent_id': '55dd585d792f2480a92bd7225d05492a',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': '9bfd242d97b34ac8189311065d549c33',
#   'text': 'As of this writing, 0x (the ZRX token) had a market cap of $307.6 million and a 24-hour trading volume of $10.5 million. It had a circulating supply of 847.5 million ZRX.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': '55dd585d792f2480a92bd7225d05492a',
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': '2cacc7e94af480a40dcffc637735bfd6',
#   'text': 'How the 0x (ZRX) Protocol Worked',
#   'metadata': {'category_depth': 1,
#    'emphasized_text_contents': ['How the 0x (ZRX) Protocol Worked'],
#    'emphasized_text_tags': ['span'],
#    'languages': ['eng'],
#    'parent_id': '1d6f144c0ca8b86aac2de00ae1523abe',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': '929039027528050d9f9ccacded947988',
#   'text': 'The protocol set up a system of makers, takers, and relayers. Makers were the users who placed orders on the exchange proxy and waited for a match (providing liquidity). Takers placed orders that were immediately matched (removing liquidity). Relayers were network participants who maintained the order book, acting similarly to an exchange.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': '2cacc7e94af480a40dcffc637735bfd6',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': 'f2a42e85bfe891265f6086b6604dcc6f',
#   'text': 'The 0x protocol’s message format was composed of a set of data fields that carried vital information, such as the digital asset or token to be traded, the price value of the transaction, the expiration time, and the defined identities of the transacting parties.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': '2cacc7e94af480a40dcffc637735bfd6',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': '85797b4bcd4ecb9db714e870ed06930f',
#   'text': 'Smart contracts took\xa0care of the necessary business logic for generating, sending, receiving, and processing the data linked to the\xa0trading activity. ZRX was 0x’s native governance and staking token. ZRX owners had a say in how the protocol evolved, and token holders could also stake their tokens to earn ETH (the Ethereum token ether) liquidity rewards.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': '2cacc7e94af480a40dcffc637735bfd6',
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': '96b16023242a74c90ffa0a5ac35906b4',
#   'text': 'The Future of 0x (ZRK)',
#   'metadata': {'category_depth': 1,
#    'emphasized_text_contents': ['The Future of 0x (ZRK)'],
#    'emphasized_text_tags': ['span'],
#    'languages': ['eng'],
#    'parent_id': '1d6f144c0ca8b86aac2de00ae1523abe',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': '2c7283e8715b234466b8ee9b9cf666d5',
#   'text': "0x's future is somewhat unclear, as its market cap and price have continued a general downward trend since its introduction. Having been shut down by regulators in 2023, the protocol and its few remaining fans don't have many options unless it transitions from exchange services or registered with the CFTC.",
#   'metadata': {'languages': ['eng'],
#    'parent_id': '96b16023242a74c90ffa0a5ac35906b4',
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': '509275ae9f8a8c80cb494178e686c237',
#   'text': 'What Is the 0x Protocol?',
#   'metadata': {'category_depth': 1,
#    'languages': ['eng'],
#    'parent_id': '1d6f144c0ca8b86aac2de00ae1523abe',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': 'ee3d59346000c9f87a42ad05683e3d12',
#   'text': '0x was a protocol for the Ethereum blockchain. It facilitated peer-to-peer exchanges of assets built using Ethereum. The project was shut down by the CFTC for operating as an unregistered exchange and abandoned by its developers.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': '509275ae9f8a8c80cb494178e686c237',
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': 'e1f202901de3c238939677bb50e234f7',
#   'text': 'What Is a 0x Exchange Proxy?',
#   'metadata': {'category_depth': 1,
#    'languages': ['eng'],
#    'parent_id': '1d6f144c0ca8b86aac2de00ae1523abe',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': '984d8eba274cff31ccb7af0cd20af27f',
#   'text': 'A 0x exchange proxy was an entity that allowed applications to be developed using the protocol.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': 'e1f202901de3c238939677bb50e234f7',
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': 'c6f5c0059bd635d96bc878e03c4a9e30',
#   'text': 'What Is the Price Prediction for 0x Protocol?',
#   'metadata': {'category_depth': 1,
#    'languages': ['eng'],
#    'parent_id': '1d6f144c0ca8b86aac2de00ae1523abe',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': 'd233ea0ed38ee2722f0412361b8aa6eb',
#   'text': 'Although the project has been abandoned, there is still ZRX trading activity. However, as there is no active development, ZRX is likely to continue to decline in market value.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': 'c6f5c0059bd635d96bc878e03c4a9e30',
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': '9203c079aa6c66e52f2b8f31ed120923',
#   'text': 'The Bottom Line',
#   'metadata': {'category_depth': 1,
#    'emphasized_text_contents': ['The Bottom Line'],
#    'emphasized_text_tags': ['span'],
#    'languages': ['eng'],
#    'parent_id': '1d6f144c0ca8b86aac2de00ae1523abe',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': '6606f6d2191148d686e1a31e0cba5e97',
#   'text': 'The 0z protocol allowed users to exchange assets using the Ethereum blockchain. In 2023, the CFTC shut it down for operating as an unregistered exchange.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': '9203c079aa6c66e52f2b8f31ed120923',
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': 'b0104b674fd952c7074c6323f172e7c4',
#   'text': 'The comments, opinions, and analyses expressed on Investopedia are for informational purposes only. Read our warranty and liability disclaimer\xa0for more info. As of the date this article was written, the author does not own ZRX.',
#   'metadata': {'emphasized_text_contents': ['The comments, opinions, and analyses expressed on Investopedia are for informational purposes only. Read our warranty and liability disclaimer\xa0for more info. As of the date this article was written, the author does not own ZRX.'],
#    'emphasized_text_tags': ['em'],
#    'link_texts': ['warranty and liability disclaimer'],
#    'link_urls': ['https://www.google.com/url?q=https://www.investopedia.com/legal-4768893%23toc-warranty-and-liability-disclaimer&sa=D&source=editors&ust=1719413657792838&usg=AOvVaw0D_UGuH-JIbePg6j211pnx'],
#    'link_start_indexes': [109],
#    'languages': ['eng'],
#    'parent_id': '9203c079aa6c66e52f2b8f31ed120923',
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': '8372e17e863b0f806e2b3e4bf4a5f9e7',
#   'text': 'Article Sources',
#   'metadata': {'category_depth': 0,
#    'languages': ['eng'],
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': 'a2653d9138c887b95075428577ca75e5',
#   'text': 'Investopedia requires writers to use primary sources to support their work. These include white papers, government data, original reporting, and interviews with industry experts. We also reference original research from other reputable publishers where appropriate. You can learn more about the standards we follow in producing accurate, unbiased content in our\n',
#   'metadata': {'emphasized_text_contents': ['editorial policy.'],
#    'emphasized_text_tags': ['span'],
#    'link_texts': [''],
#    'link_urls': ['https://www.investopedia.com/legal-4768893#EditorialPolicy'],
#    'link_start_indexes': [362],
#    'languages': ['eng'],
#    'parent_id': '8372e17e863b0f806e2b3e4bf4a5f9e7',
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': '32e1fb312bd65774ba3005747c705400',
#   'text': 'editorial policy.',
#   'metadata': {'category_depth': 0,
#    'emphasized_text_contents': ['editorial policy.'],
#    'emphasized_text_tags': ['span'],
#    'link_texts': ['editorial policy.'],
#    'link_urls': ['https://www.investopedia.com/legal-4768893#EditorialPolicy'],
#    'link_start_indexes': [-1],
#    'languages': ['eng'],
#    'filetype': 'text/html'}},
#  {'type': 'ListItem',
#   'element_id': 'af76751e52bb031f03e5d00ebf63a7b8',
#   'text': 'ICODrops. "0x ZRX."',
#   'metadata': {'category_depth': 1,
#    'link_texts': ['0x ZRX'],
#    'link_urls': ['https://icodrops.com/0x/'],
#    'link_start_indexes': [11],
#    'languages': ['eng'],
#    'parent_id': '32e1fb312bd65774ba3005747c705400',
#    'filetype': 'text/html'}},
#  {'type': 'ListItem',
#   'element_id': '32433b0b3ee912e60a88d0d9e3ee06a2',
#   'text': '0x Protocol. "Introducing the 0x DAO."',
#   'metadata': {'category_depth': 1,
#    'link_texts': ['Introducing the 0x DAO'],
#    'link_urls': ['https://forum.0xprotocol.org/t/introducing-the-0x-dao/731'],
#    'link_start_indexes': [14],
#    'languages': ['eng'],
#    'parent_id': '32e1fb312bd65774ba3005747c705400',
#    'filetype': 'text/html'}},
#  {'type': 'ListItem',
#   'element_id': '7964f8fab96255be256643c008053ec6',
#   'text': 'Commodities Futures Trading Commission. "CFTC Issues Orders Against Operators of Three DeFi Protocols for Offering Illegal Digital Asset Derivatives Trading."',
#   'metadata': {'category_depth': 1,
#    'link_texts': ['CFTC Issues Orders Against Operators of Three DeFi Protocols for Offering Illegal Digital Asset Derivatives Trading'],
#    'link_urls': ['https://www.cftc.gov/PressRoom/PressReleases/8774-23'],
#    'link_start_indexes': [41],
#    'languages': ['eng'],
#    'parent_id': '32e1fb312bd65774ba3005747c705400',
#    'filetype': 'text/html'}},
#  {'type': 'ListItem',
#   'element_id': '3b470464f9afb2df352d0294b69c5573',
#   'text': 'Reddit. "r|0xProject."',
#   'metadata': {'category_depth': 1,
#    'link_texts': ['r|0xProject'],
#    'link_urls': ['https://www.reddit.com/r/0xProject/comments/1bdatc1/this_subreddit_not_actively_monitored_links_for/'],
#    'link_start_indexes': [9],
#    'languages': ['eng'],
#    'parent_id': '32e1fb312bd65774ba3005747c705400',
#    'filetype': 'text/html'}},
#  {'type': 'ListItem',
#   'element_id': '4fb4328c37053464fbb80b65bd4aaa3f',
#   'text': '0xProtocol. "Forum."',
#   'metadata': {'category_depth': 1,
#    'link_texts': ['Forum'],
#    'link_urls': ['https://forum.0xprotocol.org/'],
#    'link_start_indexes': [13],
#    'languages': ['eng'],
#    'parent_id': '32e1fb312bd65774ba3005747c705400',
#    'filetype': 'text/html'}},
#  {'type': 'ListItem',
#   'element_id': '697bed29f7b6160fee4ab63cb6d131c3',
#   'text': 'CoinMarketCap. "0x Protocol (ZRX)."',
#   'metadata': {'category_depth': 1,
#    'link_texts': ['0x Protocol (ZRX)'],
#    'link_urls': ['https://coinmarketcap.com/currencies/0x/'],
#    'link_start_indexes': [16],
#    'languages': ['eng'],
#    'parent_id': '32e1fb312bd65774ba3005747c705400',
#    'filetype': 'text/html'}},
#  {'type': 'ListItem',
#   'element_id': 'daa958f37d2c31ebbfa9f209ac7ac67d',
#   'text': 'Github. "0x Project | Whitepaper," Page 6.',
#   'metadata': {'category_depth': 1,
#    'link_texts': ['0x Project | Whitepaper'],
#    'link_urls': ['https://github.com/0xProject/whitepaper/blob/master/0x_white_paper.pdf'],
#    'link_start_indexes': [9],
#    'languages': ['eng'],
#    'parent_id': '32e1fb312bd65774ba3005747c705400',
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': '73079147d6ba119aacace9c192f72af2',
#   'text': 'Compare Accounts',
#   'metadata': {'category_depth': 0,
#    'languages': ['eng'],
#    'filetype': 'text/html'}},
#  {'type': 'NarrativeText',
#   'element_id': 'ce33d0d328f733331b8528eefe8a0c8a',
#   'text': 'The offers that appear in this table are from partnerships from which Investopedia receives compensation. This compensation may impact how and where listings appear. Investopedia does not include all offers available in the marketplace.',
#   'metadata': {'languages': ['eng'],
#    'parent_id': '73079147d6ba119aacace9c192f72af2',
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': 'af2bd98474aa0629a894fb466138ed2e',
#   'text': 'Provider',
#   'metadata': {'category_depth': 0,
#    'languages': ['eng'],
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': '72703a9ff1a47b1a9fd77d812e83a0c2',
#   'text': 'Name',
#   'metadata': {'category_depth': 0,
#    'languages': ['eng'],
#    'filetype': 'text/html'}},
#  {'type': 'Title',
#   'element_id': '96b10667e15f5cb84491478c5417835a',
#   'text': 'Description',
#   'metadata': {'category_depth': 0,
#    'languages': ['eng'],
#    'filetype': 'text/html'}}]

# %%
def create_cleaned_json(data):
    exclude_titles = {"Close", "The Bottom Line", "Article Sources", "Compare Accounts"}

    # Remove any Title element with the text "Close"
    data = [el for el in data if not (el['type'] == 'Title' and el['text'] in exclude_titles)]

    # Extract the first title as metadata
    first_title = None
    for el in data:
        if el['type'] == 'Title':
            first_title = el
            break

    # Create a mapping of element_id to title
    title_mapping = {el['element_id']: el for el in data if el['type'] == 'Title'}

    # Create a list to hold the cleaned JSON objects
    cleaned_data = []

    # Iterate over the elements to link NarrativeText with their parent titles
    for el in data:
        if el['type'] == 'NarrativeText':
            parent_id = el['metadata'].get('parent_id')
            if parent_id in title_mapping:
                # Find the corresponding title
                parent_title = title_mapping[parent_id]
                # Check if the title is already in cleaned_data
                title_obj = next((item for item in cleaned_data if item['element_id'] == parent_id), None)
                if title_obj:
                    # Add the NarrativeText to the existing title
                    title_obj['narratives'].append(el)
                else:
                    # Create a new title object and add it to cleaned_data
                    title_obj = parent_title.copy()
                    title_obj['narratives'] = [el]
                    cleaned_data.append(title_obj)

    # Include the first title as metadata
    cleaned_json = {
        'metadata': first_title,
        'data': cleaned_data
    }

    return cleaned_json

# Create the cleaned JSON object
cleaned_json = create_cleaned_json(record)

# Print the cleaned JSON
print(json.dumps(cleaned_json, indent=2))
# Out:
# {
#   "metadata": {
#     "type": "Title",
#     "element_id": "7ffe2592fb17a9276e7a6567c2458cd7",
#     "text": "0x (ZRX) Protocol: What It Meant and How It Worked",
#     "metadata": {
#       "category_depth": 0,
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     }
#   },
#   "data": [
#     {
#       "type": "Title",
#       "element_id": "d289e028f60bbbeb5cd3309880545e7c",
#       "text": "What Was the 0x (ZRX) Protocol?",
#       "metadata": {
#         "category_depth": 1,
#         "emphasized_text_contents": [
#           "What Was the 0x (ZRX) Protocol?"
#         ],
#         "emphasized_text_tags": [
#           "span"
#         ],
#         "languages": [
#           "eng"
#         ],
#         "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#         "filetype": "text/html"
#       },
#       "narratives": [
#         {
#           "type": "NarrativeText",
#           "element_id": "9923862f4a4d5b34ef5900d1f96089fe",
#           "text": "The 0x (zero x) protocol enabled the peer-to-peer exchange of assets on the Ethereum blockchain. It was launched in 2017 by ZeroEx Labs, an organization based in San Francisco. The protocol itself was not, by the developer's definition, a decentralized exchange; it allowed for the creation of decentralized exchanges that can be used in broad applications.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "d289e028f60bbbeb5cd3309880545e7c",
#             "filetype": "text/html"
#           }
#         },
#         {
#           "type": "NarrativeText",
#           "element_id": "2f876c5500fb7fe7319d5deb69e138e3",
#           "text": "However, the Commodities and Futures Trading Commission disagreed\u2014it shut down the 0x protocol in September 2023 for operating as an unregistered exchange, and its developers were fined $200,000.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "d289e028f60bbbeb5cd3309880545e7c",
#             "filetype": "text/html"
#           }
#         }
#       ]
#     },
#     {
#       "type": "Title",
#       "element_id": "55dd585d792f2480a92bd7225d05492a",
#       "text": "The History of 0x (ZRX) Protocol",
#       "metadata": {
#         "category_depth": 1,
#         "emphasized_text_contents": [
#           "The History of 0x (ZRX) Protocol"
#         ],
#         "emphasized_text_tags": [
#           "span"
#         ],
#         "languages": [
#           "eng"
#         ],
#         "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#         "filetype": "text/html"
#       },
#       "narratives": [
#         {
#           "type": "NarrativeText",
#           "element_id": "55cc60f9003e7fc25c2936ee68147039",
#           "text": "0x was founded by Will Warren and Amir Bandeali in 2017, who launched an initial coin offering in 2017. The ICO was a success, raising $24 million and another $85 million between two fundraising rounds between 2021 and 2022.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "55dd585d792f2480a92bd7225d05492a",
#             "filetype": "text/html"
#           }
#         },
#         {
#           "type": "NarrativeText",
#           "element_id": "8a322c40d430a22191f98071f722d5a4",
#           "text": "The secondary protocol was created on Ethereum to act as a settlement layer for trading ERC 20 tokens. ERC 20 tokens are fungible (exchangeable) tokens that follow the standards set by Ethereum Request for Comment 20.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "55dd585d792f2480a92bd7225d05492a",
#             "filetype": "text/html"
#           }
#         },
#         {
#           "type": "NarrativeText",
#           "element_id": "710bc9a6458a8f57048642203c29d9d6",
#           "text": "In 2021, 0x launched the 0x Decentralized Autonomous Organization (DAO), the organization that would allow participants to govern the progress of the project.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "55dd585d792f2480a92bd7225d05492a",
#             "filetype": "text/html"
#           }
#         },
#         {
#           "type": "NarrativeText",
#           "element_id": "c2b5ef40702f0243386aed964c172118",
#           "text": "But in September 2023, the Commodities and Futures Trading Commission filed and settled charges against ZeroEx, Inc, along with two other digital asset exchanges, Opyn, Inc, and Deridex. Charges included failing to register as a futures commission merchant, failing to register as a swap execution facility, and illegally offering leveraged and margined retail commodity transactions.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "55dd585d792f2480a92bd7225d05492a",
#             "filetype": "text/html"
#           }
#         },
#         {
#           "type": "NarrativeText",
#           "element_id": "e97fea971227ed5da670330c9a275609",
#           "text": "ZeroEx was ordered to pay $200,000 in fines and cease operating as an exchange. As of June 26, 2024, the project community was very small, and the 0x Project's Reddit page had been abandoned.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "55dd585d792f2480a92bd7225d05492a",
#             "filetype": "text/html"
#           }
#         },
#         {
#           "type": "NarrativeText",
#           "element_id": "9bfd242d97b34ac8189311065d549c33",
#           "text": "As of this writing, 0x (the ZRX token) had a market cap of $307.6 million and a 24-hour trading volume of $10.5 million. It had a circulating supply of 847.5 million ZRX.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "55dd585d792f2480a92bd7225d05492a",
#             "filetype": "text/html"
#           }
#         }
#       ]
#     },
#     {
#       "type": "Title",
#       "element_id": "2cacc7e94af480a40dcffc637735bfd6",
#       "text": "How the 0x (ZRX) Protocol Worked",
#       "metadata": {
#         "category_depth": 1,
#         "emphasized_text_contents": [
#           "How the 0x (ZRX) Protocol Worked"
#         ],
#         "emphasized_text_tags": [
#           "span"
#         ],
#         "languages": [
#           "eng"
#         ],
#         "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#         "filetype": "text/html"
#       },
#       "narratives": [
#         {
#           "type": "NarrativeText",
#           "element_id": "929039027528050d9f9ccacded947988",
#           "text": "The protocol set up a system of makers, takers, and relayers. Makers were the users who placed orders on the exchange proxy and waited for a match (providing liquidity). Takers placed orders that were immediately matched (removing liquidity). Relayers were network participants who maintained the order book, acting similarly to an exchange.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "2cacc7e94af480a40dcffc637735bfd6",
#             "filetype": "text/html"
#           }
#         },
#         {
#           "type": "NarrativeText",
#           "element_id": "f2a42e85bfe891265f6086b6604dcc6f",
#           "text": "The 0x protocol\u2019s message format was composed of a set of data fields that carried vital information, such as the digital asset or token to be traded, the price value of the transaction, the expiration time, and the defined identities of the transacting parties.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "2cacc7e94af480a40dcffc637735bfd6",
#             "filetype": "text/html"
#           }
#         },
#         {
#           "type": "NarrativeText",
#           "element_id": "85797b4bcd4ecb9db714e870ed06930f",
#           "text": "Smart contracts took\u00a0care of the necessary business logic for generating, sending, receiving, and processing the data linked to the\u00a0trading activity. ZRX was 0x\u2019s native governance and staking token. ZRX owners had a say in how the protocol evolved, and token holders could also stake their tokens to earn ETH (the Ethereum token ether) liquidity rewards.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "2cacc7e94af480a40dcffc637735bfd6",
#             "filetype": "text/html"
#           }
#         }
#       ]
#     },
#     {
#       "type": "Title",
#       "element_id": "96b16023242a74c90ffa0a5ac35906b4",
#       "text": "The Future of 0x (ZRK)",
#       "metadata": {
#         "category_depth": 1,
#         "emphasized_text_contents": [
#           "The Future of 0x (ZRK)"
#         ],
#         "emphasized_text_tags": [
#           "span"
#         ],
#         "languages": [
#           "eng"
#         ],
#         "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#         "filetype": "text/html"
#       },
#       "narratives": [
#         {
#           "type": "NarrativeText",
#           "element_id": "2c7283e8715b234466b8ee9b9cf666d5",
#           "text": "0x's future is somewhat unclear, as its market cap and price have continued a general downward trend since its introduction. Having been shut down by regulators in 2023, the protocol and its few remaining fans don't have many options unless it transitions from exchange services or registered with the CFTC.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "96b16023242a74c90ffa0a5ac35906b4",
#             "filetype": "text/html"
#           }
#         }
#       ]
#     },
#     {
#       "type": "Title",
#       "element_id": "509275ae9f8a8c80cb494178e686c237",
#       "text": "What Is the 0x Protocol?",
#       "metadata": {
#         "category_depth": 1,
#         "languages": [
#           "eng"
#         ],
#         "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#         "filetype": "text/html"
#       },
#       "narratives": [
#         {
#           "type": "NarrativeText",
#           "element_id": "ee3d59346000c9f87a42ad05683e3d12",
#           "text": "0x was a protocol for the Ethereum blockchain. It facilitated peer-to-peer exchanges of assets built using Ethereum. The project was shut down by the CFTC for operating as an unregistered exchange and abandoned by its developers.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "509275ae9f8a8c80cb494178e686c237",
#             "filetype": "text/html"
#           }
#         }
#       ]
#     },
#     {
#       "type": "Title",
#       "element_id": "e1f202901de3c238939677bb50e234f7",
#       "text": "What Is a 0x Exchange Proxy?",
#       "metadata": {
#         "category_depth": 1,
#         "languages": [
#           "eng"
#         ],
#         "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#         "filetype": "text/html"
#       },
#       "narratives": [
#         {
#           "type": "NarrativeText",
#           "element_id": "984d8eba274cff31ccb7af0cd20af27f",
#           "text": "A 0x exchange proxy was an entity that allowed applications to be developed using the protocol.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "e1f202901de3c238939677bb50e234f7",
#             "filetype": "text/html"
#           }
#         }
#       ]
#     },
#     {
#       "type": "Title",
#       "element_id": "c6f5c0059bd635d96bc878e03c4a9e30",
#       "text": "What Is the Price Prediction for 0x Protocol?",
#       "metadata": {
#         "category_depth": 1,
#         "languages": [
#           "eng"
#         ],
#         "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#         "filetype": "text/html"
#       },
#       "narratives": [
#         {
#           "type": "NarrativeText",
#           "element_id": "d233ea0ed38ee2722f0412361b8aa6eb",
#           "text": "Although the project has been abandoned, there is still ZRX trading activity. However, as there is no active development, ZRX is likely to continue to decline in market value.",
#           "metadata": {
#             "languages": [
#               "eng"
#             ],
#             "parent_id": "c6f5c0059bd635d96bc878e03c4a9e30",
#             "filetype": "text/html"
#           }
#         }
#       ]
#     }
#   ]
# }

# %%
# Function to format the cleaned JSON data

def transform_cleaned_data(data):
    # Extract metadata
    first_title = data["metadata"]
    
    # List to store the transformed data
    transformed_data = []

    # Add the first title to the transformed data
    transformed_data.append(first_title)

    # Process each title and its narratives
    for item in data["data"]:
        # Add the title to the transformed data
        transformed_data.append(item)
        # Add each narrative text associated with the title
        for narrative in item.get("narratives", []):
            transformed_data.append(narrative)
    
    return transformed_data

# %%
#Testing format
# Transform the cleaned data
transformed_data = transform_cleaned_data(cleaned_json)

# Convert to JSON
transformed_json = json.dumps(transformed_data, indent=2)

# Print the transformed JSON
print(transformed_json)
# Out:
# [
#   {
#     "type": "Title",
#     "element_id": "7ffe2592fb17a9276e7a6567c2458cd7",
#     "text": "0x (ZRX) Protocol: What It Meant and How It Worked",
#     "metadata": {
#       "category_depth": 0,
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "d289e028f60bbbeb5cd3309880545e7c",
#     "text": "What Was the 0x (ZRX) Protocol?",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "What Was the 0x (ZRX) Protocol?"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "9923862f4a4d5b34ef5900d1f96089fe",
#         "text": "The 0x (zero x) protocol enabled the peer-to-peer exchange of assets on the Ethereum blockchain. It was launched in 2017 by ZeroEx Labs, an organization based in San Francisco. The protocol itself was not, by the developer's definition, a decentralized exchange; it allowed for the creation of decentralized exchanges that can be used in broad applications.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "d289e028f60bbbeb5cd3309880545e7c",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "2f876c5500fb7fe7319d5deb69e138e3",
#         "text": "However, the Commodities and Futures Trading Commission disagreed\u2014it shut down the 0x protocol in September 2023 for operating as an unregistered exchange, and its developers were fined $200,000.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "d289e028f60bbbeb5cd3309880545e7c",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "9923862f4a4d5b34ef5900d1f96089fe",
#     "text": "The 0x (zero x) protocol enabled the peer-to-peer exchange of assets on the Ethereum blockchain. It was launched in 2017 by ZeroEx Labs, an organization based in San Francisco. The protocol itself was not, by the developer's definition, a decentralized exchange; it allowed for the creation of decentralized exchanges that can be used in broad applications.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "d289e028f60bbbeb5cd3309880545e7c",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "2f876c5500fb7fe7319d5deb69e138e3",
#     "text": "However, the Commodities and Futures Trading Commission disagreed\u2014it shut down the 0x protocol in September 2023 for operating as an unregistered exchange, and its developers were fined $200,000.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "d289e028f60bbbeb5cd3309880545e7c",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "55dd585d792f2480a92bd7225d05492a",
#     "text": "The History of 0x (ZRX) Protocol",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "The History of 0x (ZRX) Protocol"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "55cc60f9003e7fc25c2936ee68147039",
#         "text": "0x was founded by Will Warren and Amir Bandeali in 2017, who launched an initial coin offering in 2017. The ICO was a success, raising $24 million and another $85 million between two fundraising rounds between 2021 and 2022.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "55dd585d792f2480a92bd7225d05492a",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "8a322c40d430a22191f98071f722d5a4",
#         "text": "The secondary protocol was created on Ethereum to act as a settlement layer for trading ERC 20 tokens. ERC 20 tokens are fungible (exchangeable) tokens that follow the standards set by Ethereum Request for Comment 20.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "55dd585d792f2480a92bd7225d05492a",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "710bc9a6458a8f57048642203c29d9d6",
#         "text": "In 2021, 0x launched the 0x Decentralized Autonomous Organization (DAO), the organization that would allow participants to govern the progress of the project.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "55dd585d792f2480a92bd7225d05492a",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "c2b5ef40702f0243386aed964c172118",
#         "text": "But in September 2023, the Commodities and Futures Trading Commission filed and settled charges against ZeroEx, Inc, along with two other digital asset exchanges, Opyn, Inc, and Deridex. Charges included failing to register as a futures commission merchant, failing to register as a swap execution facility, and illegally offering leveraged and margined retail commodity transactions.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "55dd585d792f2480a92bd7225d05492a",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "e97fea971227ed5da670330c9a275609",
#         "text": "ZeroEx was ordered to pay $200,000 in fines and cease operating as an exchange. As of June 26, 2024, the project community was very small, and the 0x Project's Reddit page had been abandoned.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "55dd585d792f2480a92bd7225d05492a",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "9bfd242d97b34ac8189311065d549c33",
#         "text": "As of this writing, 0x (the ZRX token) had a market cap of $307.6 million and a 24-hour trading volume of $10.5 million. It had a circulating supply of 847.5 million ZRX.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "55dd585d792f2480a92bd7225d05492a",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "55cc60f9003e7fc25c2936ee68147039",
#     "text": "0x was founded by Will Warren and Amir Bandeali in 2017, who launched an initial coin offering in 2017. The ICO was a success, raising $24 million and another $85 million between two fundraising rounds between 2021 and 2022.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "55dd585d792f2480a92bd7225d05492a",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "8a322c40d430a22191f98071f722d5a4",
#     "text": "The secondary protocol was created on Ethereum to act as a settlement layer for trading ERC 20 tokens. ERC 20 tokens are fungible (exchangeable) tokens that follow the standards set by Ethereum Request for Comment 20.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "55dd585d792f2480a92bd7225d05492a",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "710bc9a6458a8f57048642203c29d9d6",
#     "text": "In 2021, 0x launched the 0x Decentralized Autonomous Organization (DAO), the organization that would allow participants to govern the progress of the project.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "55dd585d792f2480a92bd7225d05492a",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "c2b5ef40702f0243386aed964c172118",
#     "text": "But in September 2023, the Commodities and Futures Trading Commission filed and settled charges against ZeroEx, Inc, along with two other digital asset exchanges, Opyn, Inc, and Deridex. Charges included failing to register as a futures commission merchant, failing to register as a swap execution facility, and illegally offering leveraged and margined retail commodity transactions.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "55dd585d792f2480a92bd7225d05492a",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "e97fea971227ed5da670330c9a275609",
#     "text": "ZeroEx was ordered to pay $200,000 in fines and cease operating as an exchange. As of June 26, 2024, the project community was very small, and the 0x Project's Reddit page had been abandoned.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "55dd585d792f2480a92bd7225d05492a",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "9bfd242d97b34ac8189311065d549c33",
#     "text": "As of this writing, 0x (the ZRX token) had a market cap of $307.6 million and a 24-hour trading volume of $10.5 million. It had a circulating supply of 847.5 million ZRX.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "55dd585d792f2480a92bd7225d05492a",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "2cacc7e94af480a40dcffc637735bfd6",
#     "text": "How the 0x (ZRX) Protocol Worked",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "How the 0x (ZRX) Protocol Worked"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "929039027528050d9f9ccacded947988",
#         "text": "The protocol set up a system of makers, takers, and relayers. Makers were the users who placed orders on the exchange proxy and waited for a match (providing liquidity). Takers placed orders that were immediately matched (removing liquidity). Relayers were network participants who maintained the order book, acting similarly to an exchange.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "2cacc7e94af480a40dcffc637735bfd6",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "f2a42e85bfe891265f6086b6604dcc6f",
#         "text": "The 0x protocol\u2019s message format was composed of a set of data fields that carried vital information, such as the digital asset or token to be traded, the price value of the transaction, the expiration time, and the defined identities of the transacting parties.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "2cacc7e94af480a40dcffc637735bfd6",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "85797b4bcd4ecb9db714e870ed06930f",
#         "text": "Smart contracts took\u00a0care of the necessary business logic for generating, sending, receiving, and processing the data linked to the\u00a0trading activity. ZRX was 0x\u2019s native governance and staking token. ZRX owners had a say in how the protocol evolved, and token holders could also stake their tokens to earn ETH (the Ethereum token ether) liquidity rewards.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "2cacc7e94af480a40dcffc637735bfd6",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "929039027528050d9f9ccacded947988",
#     "text": "The protocol set up a system of makers, takers, and relayers. Makers were the users who placed orders on the exchange proxy and waited for a match (providing liquidity). Takers placed orders that were immediately matched (removing liquidity). Relayers were network participants who maintained the order book, acting similarly to an exchange.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "2cacc7e94af480a40dcffc637735bfd6",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "f2a42e85bfe891265f6086b6604dcc6f",
#     "text": "The 0x protocol\u2019s message format was composed of a set of data fields that carried vital information, such as the digital asset or token to be traded, the price value of the transaction, the expiration time, and the defined identities of the transacting parties.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "2cacc7e94af480a40dcffc637735bfd6",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "85797b4bcd4ecb9db714e870ed06930f",
#     "text": "Smart contracts took\u00a0care of the necessary business logic for generating, sending, receiving, and processing the data linked to the\u00a0trading activity. ZRX was 0x\u2019s native governance and staking token. ZRX owners had a say in how the protocol evolved, and token holders could also stake their tokens to earn ETH (the Ethereum token ether) liquidity rewards.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "2cacc7e94af480a40dcffc637735bfd6",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "96b16023242a74c90ffa0a5ac35906b4",
#     "text": "The Future of 0x (ZRK)",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "The Future of 0x (ZRK)"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "2c7283e8715b234466b8ee9b9cf666d5",
#         "text": "0x's future is somewhat unclear, as its market cap and price have continued a general downward trend since its introduction. Having been shut down by regulators in 2023, the protocol and its few remaining fans don't have many options unless it transitions from exchange services or registered with the CFTC.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "96b16023242a74c90ffa0a5ac35906b4",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "2c7283e8715b234466b8ee9b9cf666d5",
#     "text": "0x's future is somewhat unclear, as its market cap and price have continued a general downward trend since its introduction. Having been shut down by regulators in 2023, the protocol and its few remaining fans don't have many options unless it transitions from exchange services or registered with the CFTC.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "96b16023242a74c90ffa0a5ac35906b4",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "509275ae9f8a8c80cb494178e686c237",
#     "text": "What Is the 0x Protocol?",
#     "metadata": {
#       "category_depth": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "ee3d59346000c9f87a42ad05683e3d12",
#         "text": "0x was a protocol for the Ethereum blockchain. It facilitated peer-to-peer exchanges of assets built using Ethereum. The project was shut down by the CFTC for operating as an unregistered exchange and abandoned by its developers.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "509275ae9f8a8c80cb494178e686c237",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "ee3d59346000c9f87a42ad05683e3d12",
#     "text": "0x was a protocol for the Ethereum blockchain. It facilitated peer-to-peer exchanges of assets built using Ethereum. The project was shut down by the CFTC for operating as an unregistered exchange and abandoned by its developers.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "509275ae9f8a8c80cb494178e686c237",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "e1f202901de3c238939677bb50e234f7",
#     "text": "What Is a 0x Exchange Proxy?",
#     "metadata": {
#       "category_depth": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "984d8eba274cff31ccb7af0cd20af27f",
#         "text": "A 0x exchange proxy was an entity that allowed applications to be developed using the protocol.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "e1f202901de3c238939677bb50e234f7",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "984d8eba274cff31ccb7af0cd20af27f",
#     "text": "A 0x exchange proxy was an entity that allowed applications to be developed using the protocol.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "e1f202901de3c238939677bb50e234f7",
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "c6f5c0059bd635d96bc878e03c4a9e30",
#     "text": "What Is the Price Prediction for 0x Protocol?",
#     "metadata": {
#       "category_depth": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "d233ea0ed38ee2722f0412361b8aa6eb",
#         "text": "Although the project has been abandoned, there is still ZRX trading activity. However, as there is no active development, ZRX is likely to continue to decline in market value.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "c6f5c0059bd635d96bc878e03c4a9e30",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "d233ea0ed38ee2722f0412361b8aa6eb",
#     "text": "Although the project has been abandoned, there is still ZRX trading activity. However, as there is no active development, ZRX is likely to continue to decline in market value.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "c6f5c0059bd635d96bc878e03c4a9e30",
#       "filetype": "text/html"
#     }
#   }
# ]

# %%
# Function to process each record and accumulate the results
def process_and_accumulate_records(df_records, all_cleaned_jsons):
    for index, row in df_records.iterrows():
        record_id = row['id']
        processed_json_str = row['processed_json']
        processed_json = json.loads(processed_json_str)
        
        # Process the record
        cleaned_json = create_cleaned_json(processed_json)
        
        # Add to the list of all cleaned JSON objects
        all_cleaned_jsons.append(cleaned_json)

# %%
# Connect to the SQLite database
conn = sqlite3.connect('investopedia_cleaned.db')

# Load all records into a pandas DataFrame
query = "SELECT id, processed_json FROM investopedia"
df_records = pd.read_sql_query(query, conn)

# Ensure the output directory exists
output_dir = "cleaned_json_files"
os.makedirs(output_dir, exist_ok=True)

# List to hold all cleaned JSON objects
all_cleaned_jsons = []

# Process all records
process_and_accumulate_records(df_records, all_cleaned_jsons)

# Convert the list of all cleaned JSON objects to a JSON string
all_cleaned_json_str = json.dumps(all_cleaned_jsons, indent=2)

# Define the output file path
output_file_path = "all_cleaned_records.txt"

# Save all cleaned JSON to a single text file
with open(output_file_path, 'w') as output_file:
    output_file.write(all_cleaned_json_str)

# Close the connection
conn.close()

print(f"All cleaned JSON records have been saved to: {output_file_path}")
# Out:
# All cleaned JSON records have been saved to: all_cleaned_records.txt

# %%
# Search for titles containing 'protocol'
titles_with_protocol = []

for record in all_cleaned_jsons:
    # Check the metadata title first
    if record.get('metadata') and record['metadata'].get('text') and 'stock' in record['metadata']['text'].lower():
        titles_with_protocol.append(record['metadata'])
    
    # Check the titles within the data
    for item in record.get('data', []):
        if item.get('type') == 'Title' and item.get('text') and 'stock' in item['text'].lower():
            titles_with_protocol.append(item)

# Print the found titles
print(json.dumps(titles_with_protocol, indent=2))
# Out:
# [
#   {
#     "type": "Title",
#     "element_id": "aa57dfff1cba93ad5ccf37ad6dd8751a",
#     "text": "130-30 Strategy and Shorting Stocks",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "130-30 Strategy and Shorting Stocks"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "4540fdc00ec36ba72f547e107e921f30",
#         "text": "The 130-30 strategy incorporates short sales as a significant part of its activity. Shorting a stock entails borrowing securities from another party, most often a broker, and agreeing to pay an interest rate as a fee. A negative position is subsequently recorded in the investor\u2019s account. The investor then sells the newly acquired securities on the open market at the current price and receives the cash for the trade. The investor waits for the securities to depreciate and then re-purchases them at a lower price. At this point, the investor returns the purchased securities to the broker. In a reverse activity from first buying and then selling securities, shorting still allows the investor to profit.",
#         "metadata": {
#           "link_texts": [
#             "open market"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/o/open-market.asp"
#           ],
#           "link_start_indexes": [
#             351
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "aa57dfff1cba93ad5ccf37ad6dd8751a",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "715a9fef1f89a570a5ea6022f914a988",
#         "text": "Short selling is much riskier than investing in long positions in securities; thus, in a 130-30 investment strategy, a manager will put more emphasis on long positions than short positions. Short-selling puts an investor in a position of unlimited risk and a capped reward. For example, if an investor shorts a stock trading at $30, the most they can gain is $30\u00a0(minus fees), while the most they can lose is infinite since the stock can technically increase in price forever.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "aa57dfff1cba93ad5ccf37ad6dd8751a",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "a2bfcf80cd6c379a41f2551d1a65010a",
#         "text": "Hedge funds and mutual fund firms have begun offering investment vehicles in the way of private equity funds, mutual funds, or even exchange-traded funds that follow variations of the 130-30 strategy. In general, these instruments have lower volatility than benchmark indexes but often fail to achieve greater total returns.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "aa57dfff1cba93ad5ccf37ad6dd8751a",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "d8b2cffbe56a5d1da51fd98a2f41d028",
#     "text": "Adjusting Prices for Stock Splits",
#     "metadata": {
#       "category_depth": 2,
#       "emphasized_text_contents": [
#         "Adjusting Prices for Stock Splits"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "5b63a378b1de096ddf1357a9fa186f51",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "0061c52e7fc6e422e6231f9e662653e4",
#         "text": "A stock split is a corporate action intended to make the firm\u2019s shares more affordable for average investors. A stock split does not change a company's total market capitalization, but it does affect the company's stock price.",
#         "metadata": {
#           "link_texts": [
#             "market capitalization"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/investing/market-capitalization-defined/"
#           ],
#           "link_start_indexes": [
#             158
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "d8b2cffbe56a5d1da51fd98a2f41d028",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "c61828132abeac02e0f83fe701a7224e",
#         "text": "For example, a company's board of directors may decide to split the company's stock 3-for-1. Therefore, the company's shares outstanding increase by a multiple of three, while its share price is divided by three. Suppose a stock closed at $300 the day before its stock split. In this case, the closing price is adjusted to $100 ($300 divided by 3) per share to maintain a consistent standard of comparison. Similarly, all other previous closing prices for that company would be divided by three to obtain the adjusted closing prices.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "d8b2cffbe56a5d1da51fd98a2f41d028",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "807774663448fc6d967374c0ea2ff815",
#     "text": "How After-Hours Trading Affects the Stock Price",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "How After-Hours Trading Affects the Stock Price"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "25d5bd195d57a1a62c278a51342c69db",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "1d84d752acd751adeda223d60290dc4c",
#         "text": "After-hours trading often has an impact on the opening price for a stock at the beginning of the next normal trading session. This is especially true if select events have occurred such as earnings release or extremely low liquidity.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "807774663448fc6d967374c0ea2ff815",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "8d5a780ca78691c76c320910c2e12f29",
#         "text": "As discussed above, because after-hours trading is usually done with a low amount of available shares, after-hours trading may result in stock movements that do not resolve until the subsequent day. This price volatility may be temporary as the market may capture spikes in price to resolve liquidity shortages of securities once regular trading hours have opened.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "807774663448fc6d967374c0ea2ff815",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "3ebc23ac16e3adde1bf1cd8dcebc02bb",
#         "text": "After-hours trading may also affect a stock price if the company has also released important news or earnings after the market has closed. Not only may this information positively or negatively impact the valuation of the security, traders may attempt to capitalize on this new information. In some situations, large enough news may invoke larger activity of after-hours traders, further increasing or decreasing the opening price on the subsequent day.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "807774663448fc6d967374c0ea2ff815",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "02890d768b96f78dcc48bb6f9876a478",
#         "text": "Last, after-hours traders may attempt to price discover, the process where buyers and sellers negotiate a price based on available supply and demand. This process may move the existing price of a stock after-hours as each side sees what sentiment of a stock may be prior to its opening the following trading period.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "807774663448fc6d967374c0ea2ff815",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "0a81d41c11fde33ad29f8a683ef6dba2",
#     "text": "Why Can Stocks Be So Volatile in After-Hours Trading?",
#     "metadata": {
#       "category_depth": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "94ee57f30d6cd6c307112dd70274b1a3",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "1cf9ef6523b5b01036871dd7fe42b2ad",
#         "text": "Lower trading volume and less liquidity results when fewer traders and investors are in the market. This causes wider bid-ask spreads and, in turn, greater stock price volatility. This is the challenging trading environment that can exist in after-hours trading.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "0a81d41c11fde33ad29f8a683ef6dba2",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "39196373eb37dc2cd3cf1aaa043b2973",
#     "text": "What Does a Negative Alpha Mean in Stocks?",
#     "metadata": {
#       "category_depth": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "5ca29722c96721d41af164714257130b",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "c919f8bc072542954d40dba971f4320d",
#         "text": "A negative alpha in stocks means that a stock is underperforming the benchmark when adjusted for risk. If an investor is intending to match or outperform a specific benchmark and their investment portfolio is performing under that rate, then their alpha is negative.",
#         "metadata": {
#           "link_texts": [
#             "negative alpha"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/ask/answers/021015/does-negative-alpha-automatically-mean-i-should-sell.asp"
#           ],
#           "link_start_indexes": [
#             2
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "39196373eb37dc2cd3cf1aaa043b2973",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "e7870b1150a43ca29455730df1eabe87",
#     "text": "Alphabet Stock: What it Means, How it Works",
#     "metadata": {
#       "category_depth": 0,
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "7c028ca813248f7b7460336cd76af8e6",
#     "text": "What Is Alphabet Stock?",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "What Is Alphabet Stock?"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "1f9e65dc30325c90ef9d2bdd9a895d42",
#         "text": "An alphabet stock refers to a separate class of common stock that is tied to a specific subsidiary of a corporation. More broadly, it refers to shares of common stock that are distinguished in some way from other common stock of the same company.",
#         "metadata": {
#           "link_texts": [
#             "common stock"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/c/commonstock.asp"
#           ],
#           "link_start_indexes": [
#             48
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "7c028ca813248f7b7460336cd76af8e6",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "100ce2e21fe4c394bc5384226cdf6e18",
#         "text": "It is called an alphabet stock because the classification system used to identify each class of common stock uses letters to distinguish it from the parent company's stock. Alphabet stock may have different\u00a0voting rights\u00a0from the parent company's stock.",
#         "metadata": {
#           "link_texts": [
#             "parent company's",
#             "voting rights"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/p/parentcompany.asp",
#             "https://www.investopedia.com/terms/v/votingright.asp"
#           ],
#           "link_start_indexes": [
#             149,
#             207
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "7c028ca813248f7b7460336cd76af8e6",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "7d0d2dda80eaefcfec080802c7c55228",
#     "text": "Understanding Alphabet Stock",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "Understanding Alphabet Stock"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "dd0dd35cdf5455d13ea17e65457ae6bb",
#         "text": "Publicly traded companies may issue alphabet stock when purchasing a business unit from another company. This unit becomes a subsidiary of the acquirer, and holders of the alphabet stock are only entitled to the earnings, dividends, and rights of the subsidiary, not the entire acquirer. A similar situation would be the issuance of tracking stock, where a firm issues a subclass of shares on an existing subsidiary.",
#         "metadata": {
#           "link_texts": [
#             "subsidiary",
#             "tracking stock"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/s/subsidiary.asp",
#             "https://www.investopedia.com/terms/t/trackingstocks.asp"
#           ],
#           "link_start_indexes": [
#             125,
#             333
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "7d0d2dda80eaefcfec080802c7c55228",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "ba7829c7892c026e45e744a96e4b6fce",
#         "text": "Alternatively, like with all stock issuance, a firm may issue a new class of common stock to raise capital. However, this new asset class of stock may have limited voting rights, allowing insiders and management to maintain control of the firm.",
#         "metadata": {
#           "link_texts": [
#             "issuance"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/i/issue.asp"
#           ],
#           "link_start_indexes": [
#             35
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "7d0d2dda80eaefcfec080802c7c55228",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "05cd0adf2ac750a516e1e20f542e9c75",
#         "text": "Alphabet\u00a0shares may be indicative of a\u00a0complex capital structure. Companies with complex capital structures and several subsidiaries and divisions may have a combination of several different varieties of common stock classes, with each share class carrying different\u00a0voting rights\u00a0and dividend rates.",
#         "metadata": {
#           "link_texts": [
#             "complex capital structure",
#             "share class"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/c/complex-capital-structure.asp",
#             "https://www.investopedia.com/terms/s/share_class.asp"
#           ],
#           "link_start_indexes": [
#             39,
#             236
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "7d0d2dda80eaefcfec080802c7c55228",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "bb099482184984f45150098336c4238f",
#     "text": "American Stock Exchange (AMEX): Definition, History, Current Name",
#     "metadata": {
#       "category_depth": 0,
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "3fc3cd670f588770e0dca303372d136c",
#     "text": "What Is the American Stock Exchange (AMEX)?",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "What Is the American Stock Exchange (AMEX)?"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "c954e3aa2906dd1e85b81245be30f240",
#         "text": "The American Stock Exchange (AMEX) was once the third-largest stock exchange in the United States, as measured by trading volume. The exchange, at its height, handled\u00a0about 10% of all securities traded in the U.S.",
#         "metadata": {
#           "link_texts": [
#             "stock exchange"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/articles/basics/04/092404.asp"
#           ],
#           "link_start_indexes": [
#             62
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "3fc3cd670f588770e0dca303372d136c",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "c128757b07889a05fae76c3afab0c4b1",
#         "text": "Today, the AMEX is known as the NYSE American. In 2008, NYSE Euronext acquired the AMEX. In the subsequent years, it also became known as NYSE Amex Equities and NYSE MKT.\ufeff\ufeff",
#         "metadata": {
#           "emphasized_text_contents": [
#             "\ufeff"
#           ],
#           "emphasized_text_tags": [
#             "span"
#           ],
#           "link_texts": [
#             "Euronext"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/e/euronext.asp"
#           ],
#           "link_start_indexes": [
#             61
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "3fc3cd670f588770e0dca303372d136c",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "9753c7efd79da4d366b6c5ab1fd94dff",
#     "text": "Understanding the American Stock Exchange (AMEX)",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "Understanding the American Stock Exchange (AMEX)"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "739cfb7f68555b93b5107ece0fb47d75",
#         "text": "The AMEX developed a reputation over time as an exchange that introduced and traded new products and asset classes. For example, it launched its options market in 1975. Options are a type of derivative security. They are contracts that grant the holder the right to buy or sell an asset at a set price on or before a certain date, without the obligation to do so. When the AMEX launched its options market, it also distributed educational materials to help educate investors as to the potential benefits and risks.\ufeff\ufeff",
#         "metadata": {
#           "emphasized_text_contents": [
#             "\ufeff"
#           ],
#           "emphasized_text_tags": [
#             "span"
#           ],
#           "link_texts": [
#             "options",
#             "derivative"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/o/option.asp",
#             "https://www.investopedia.com/terms/d/derivative.asp"
#           ],
#           "link_start_indexes": [
#             145,
#             191
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "9753c7efd79da4d366b6c5ab1fd94dff",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "f0c9dfa911273600a44fb4e2b2e80274",
#         "text": "The AMEX used to be a larger competitor of the New York Stock Exchange (NYSE), but over time the Nasdaq filled that role.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "9753c7efd79da4d366b6c5ab1fd94dff",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "16bdc15b24b4e1b6f5e6868c9a6612f8",
#         "text": "In 1993, the AMEX introduced the first exchange traded fund (ETF). The ETF, now a popular investment, is a type of security that tracks an index or a basket of assets. They are much like mutual funds but differ in that they trade like stocks on an exchange.\ufeff\ufeff",
#         "metadata": {
#           "emphasized_text_contents": [
#             "\ufeff"
#           ],
#           "emphasized_text_tags": [
#             "span"
#           ],
#           "link_texts": [
#             "exchange traded fund (ETF)",
#             "index"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/e/etf.asp",
#             "https://www.investopedia.com/terms/i/index.asp"
#           ],
#           "link_start_indexes": [
#             39,
#             139
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "9753c7efd79da4d366b6c5ab1fd94dff",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "2189f5554afebd84a5dc5782029cd72a",
#         "text": "Over time, the AMEX gained the reputation of listing companies that could not meet the strict requirements of the NYSE. Today, a good portion of trading on the NYSE American is in small cap stocks. It operates as a fully electronic exchange.",
#         "metadata": {
#           "link_texts": [
#             "small cap"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/s/small-cap.asp"
#           ],
#           "link_start_indexes": [
#             180
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "9753c7efd79da4d366b6c5ab1fd94dff",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "cc5f4d1718877c13be85bc20196dc8f5",
#     "text": "History of the American Stock Exchange (AMEX)",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "History of the American Stock Exchange (AMEX)"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "e9d695f1af31e45a78ec1384dfbafb2d",
#         "text": "The AMEX dates back to the late 18th century when the American trading market was still developing. At that time, without a formalized exchange, stockbrokers would meet in coffeehouses and on the street to trade securities. For this reason, the AMEX became known at one time as the New York Curb Exchange.\ufeff\ufeff",
#         "metadata": {
#           "emphasized_text_contents": [
#             "\ufeff"
#           ],
#           "emphasized_text_tags": [
#             "span"
#           ],
#           "link_texts": [
#             "stockbrokers"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/s/stockbroker.asp"
#           ],
#           "link_start_indexes": [
#             145
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "cc5f4d1718877c13be85bc20196dc8f5",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "43f91841ada68e94de9285e20f3fefc7",
#         "text": "The traders who originally met in the streets of New York became known as curbstone brokers. They specialized in trading stocks of emerging companies. At the time, many of these emerging businesses were in industries such as railroads, oil, and textiles, while those industries were still getting off the ground.\ufeff\ufeff",
#         "metadata": {
#           "emphasized_text_contents": [
#             "\ufeff"
#           ],
#           "emphasized_text_tags": [
#             "span"
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "cc5f4d1718877c13be85bc20196dc8f5",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "8c709f4ce04da6925fccb0ac7c869584",
#         "text": "In the 19th century, this type of curbside trading was informal and quite disorganized. In 1908, the New York Curb Market Agency was established in order to bring rules and regulations to trading practices.\ufeff\ufeff",
#         "metadata": {
#           "emphasized_text_contents": [
#             "\ufeff"
#           ],
#           "emphasized_text_tags": [
#             "span"
#           ],
#           "link_texts": [
#             "informal and quite disorganized"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/articles/07/stock-exchange-history.asp"
#           ],
#           "link_start_indexes": [
#             55
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "cc5f4d1718877c13be85bc20196dc8f5",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "41cf04ebf52d1e064ce92dd832dc4b29",
#         "text": "In 1929, the New York Curb Market became the New York Curb Exchange. It had a formalized trading floor and a set of rules and regulations. In the 1950s, more and more emerging businesses began trading their stocks on the New York Curb Exchange. The value of companies listed on the exchange almost doubled between 1950 and 1960, going from $12 billion to $23 billion during that time. The New York Curb Exchange changed its name to the American Stock Exchange in 1953.\ufeff\ufeff",
#         "metadata": {
#           "emphasized_text_contents": [
#             "\ufeff"
#           ],
#           "emphasized_text_tags": [
#             "span"
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "cc5f4d1718877c13be85bc20196dc8f5",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "5239c36bd3def2bb128bf81aa8343a97",
#     "text": "Amsterdam Stock Exchange (AEX) .AS: Meaning, How It Works",
#     "metadata": {
#       "category_depth": 0,
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "11a797903967c7c1ccf46239022a1372",
#     "text": "What Is the Amsterdam Stock Exchange (AEX) .AS?",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "What Is the Amsterdam Stock Exchange (AEX) .AS?"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "aed1f892ef813c28cbe95885b3c24ab6",
#         "text": "Founded in 1602, along with the creation of the Dutch East India Company (VOC), the Amsterdam Stock Exchange is considered the oldest, still-functioning\u00a0stock exchange in the world.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "11a797903967c7c1ccf46239022a1372",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "996fefd4381a436497d2854ef4cfc279",
#         "text": "The need for a bank grew with the prevalence of European trade and with the need to offer financiers a way to profit in this commerce. The Dutch East India Company was one of the earliest businesses to compete for the exports from the spice and slave trade. It was a joint-stock company and would offer shares to investors who would bankroll the voyages. Financiers required a safe and regulated place where buy and sell shares of these early global enterprises.",
#         "metadata": {
#           "link_texts": [
#             "joint-stock company"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/j/jointstockcompany.asp"
#           ],
#           "link_start_indexes": [
#             267
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "11a797903967c7c1ccf46239022a1372",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "83b88ff9978b4c59956d857fe3a40b05",
#         "text": "Before the AEX, many regions and towns had independent systems of asset valuation and trade regulation which operated much like stock exchanges, but the AEX was the first official stock exchange as we know it.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "11a797903967c7c1ccf46239022a1372",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "3e94d7d334a703f62450b62396ac1100",
#     "text": "The Basics of the Amsterdam Stock Exchange (AEX) .AS",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "The Basics of the Amsterdam Stock Exchange (AEX) .AS"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "0f40f7b52f424c22fb01fc3e52f88628",
#         "text": "Over its centuries-long history, the Amsterdam Stock Exchange has gone through several ownership changes and governance structures.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "3e94d7d334a703f62450b62396ac1100",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "6511952d71d91779ff874f19b469e532",
#         "text": "Looking to recent history, in 1997 the Amsterdam Stock Exchange and the European Options Exchange (EOE) merged, and its blue-chip index was renamed\u00a0AEX for \"Amsterdam Exchange.\"",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "3e94d7d334a703f62450b62396ac1100",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "c1c598c4292ee5659c033b98bf043198",
#         "text": "In September 2000, the Amsterdam Stock Exchange merged with the Brussels Stock Exchange and the Paris Stock Exchange to form Euronext Amsterdam. Euronext is Europe's largest cash equities market. For some time fell under the umbrella of NYSE Euronext, which operated several exchanges, including the New York Stock Exchange, the Liffe in London, and NYSE Arca Options. In 2014, Euronext was spun off to become an independent entity once again. As of 2017, Euronext was the sixth largest combined stock exchange by market cap.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "3e94d7d334a703f62450b62396ac1100",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "f6546473d1f4cdc771771873e7b7906c",
#         "text": "The AEX is one of Euronext's main indexes.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "3e94d7d334a703f62450b62396ac1100",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "071564d6c130ff1946bd80daa4586e14",
#     "text": "Annual Returns on Stocks",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "Annual Returns on Stocks"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "df819c52418a512cdf41eb1a61e7adb7",
#         "text": "Also known as an annualized return, the annual return expresses a stock\u2019s increase in value over a designated period. Information regarding the current price of the stock and the price at which it was purchased is required to calculate it. The purchase price must be adjusted accordingly if any splits have occurred. The simple return percentage is calculated first when the prices are determined, with that figure ultimately being annualized.",
#         "metadata": {
#           "link_texts": [
#             "annualized return"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/a/annualized-total-return.asp"
#           ],
#           "link_start_indexes": [
#             17
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "071564d6c130ff1946bd80daa4586e14",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "a17dba6a0db3f0af25ce7ffa5c22a425",
#         "text": "The simple return is the current price minus the purchase price, divided by the purchase price.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "071564d6c130ff1946bd80daa4586e14",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "841ec7995486d8c27c399d4444d03a3f",
#     "text": "Why Might an Investor Annualize a Stock\u2019s One-Month Return?",
#     "metadata": {
#       "category_depth": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "7dfa29aed4cb00a3ddb6cce3be297455",
#         "text": "Investors may annualize a stock's one-month return to forecast its performance over the next 12 months. Understanding a stock's longer-term returns can help investors better manage their risk and compare performance against other benchmarks.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "841ec7995486d8c27c399d4444d03a3f",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "ed203129bcf43e545d39d51555a19489",
#     "text": "Stock Market Spreads",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "Stock Market Spreads"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "27b64c09b42c554f140c1cdba82e7aba",
#         "text": "In 2001, stock prices changed from being quoted\u00a0in sixteenths to decimals. That brought the smallest possible spread from 1/16 of a dollar, or $.0625, to one penny. The width of a spread in nominal terms will depend in part on the price of the stock. A spread of two cents on a price of $10 is 0.02%, while a spread of two cents on a price of $100 is 0.002%.",
#         "metadata": {
#           "link_texts": [
#             "nominal"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/n/nominal.asp"
#           ],
#           "link_start_indexes": [
#             190
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "ed203129bcf43e545d39d51555a19489",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "38e7023a92d53b43fe3b5993b86b7933",
#     "text": "What Are Asset Classes? More Than Just Stocks and Bonds",
#     "metadata": {
#       "category_depth": 0,
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "65f5c210739de17efe846eb434df95b1",
#     "text": "Authorized Stock: Definition, Example, Vs. Issued Stock",
#     "metadata": {
#       "category_depth": 0,
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "9fdb7ce82ac0c8091722636c6460df46",
#     "text": "What is Authorized Stock?",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "What is Authorized Stock?"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "7cf6a3dc3a37e9005ba48d8d641b9122",
#         "text": "Authorized stock, or authorized shares, refers to the maximum number of shares that a corporation is legally permitted to issue, as specified in its articles of incorporation in the U.S., or in the company's charter in other parts of the world. It is also usually listed in the capital accounts section of the balance sheet. Authorized shares should not be confused with outstanding shares, which are the number of shares the corporation has actually issued that are held by the public.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "9fdb7ce82ac0c8091722636c6460df46",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "3b6eadc18bae7479555ef339da2e950b",
#         "text": "Authorized stock is also known as authorized shares or authorized capital stock.",
#         "metadata": {
#           "link_texts": [
#             "authorized capital stock"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/ask/answers/050115/whats-difference-between-capital-stock-and-treasury-stock.asp"
#           ],
#           "link_start_indexes": [
#             55
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "9fdb7ce82ac0c8091722636c6460df46",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "e538c594c48ad053ad3500f5d87f871f",
#     "text": "Understanding Authorized Stock",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "Understanding Authorized Stock"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "43927f6505b285b8d7d1ad20f6b5ba95",
#         "text": "When a company is formed, it decides on the maximum number of shares it would like to offer. These shares are referred to as authorized stock. The shares that\u00a0are issued to the public to trade on the open markets comprise all or a portion of a company's authorized stock. The number of shares actually available to trade is known as float. In addition, restricted shares, which\u00a0are reserved for employee compensation and incentives, are also part of authorized shares. The total number of a company's outstanding shares as seen in the balance sheet is the sum of float and restricted shares. If outstanding shares are less than authorized shares, the difference (unissued stock) is what the company retains in its treasury. A company that issues all of its authorized stock will have its outstanding shares equal to authorized shares. Outstanding shares can never exceed the authorized number, since the authorized shares total is the maximum number of shares that a company can issue.",
#         "metadata": {
#           "link_texts": [
#             "float",
#             "restricted shares",
#             "outstanding shares",
#             "treasury"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/f/floating-stock.asp",
#             "https://www.investopedia.com/terms/r/restrictedstock.asp",
#             "https://www.investopedia.com/terms/o/outstandingshares.asp",
#             "https://www.investopedia.com/terms/t/treasurystock.asp"
#           ],
#           "link_start_indexes": [
#             333,
#             353,
#             501,
#             714
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "e538c594c48ad053ad3500f5d87f871f",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "7ac6e4e5eeba9e20b88bc793bc976238",
#     "text": "Example of Authorized Stock",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "Example of Authorized Stock"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "43b6179eed759406bdd7548151b370f6",
#         "text": "Amazon\u2019s corporate charter, for example, states that the company\u2019s total authorized stock shall include 5 billion shares of common stock and 500 million shares of preferred stock. The charter permits Amazon to increase its authorized stock if there isn\u2019t enough unissued common stock to allow for the conversion of preferred stock.\ufeff\ufeff Corporate charters often require shareholder approval to increase the number of shares of authorized stock.",
#         "metadata": {
#           "emphasized_text_contents": [
#             "\ufeff"
#           ],
#           "emphasized_text_tags": [
#             "span"
#           ],
#           "link_texts": [
#             "corporate charter",
#             "preferred stock"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/c/corporatecharter.asp",
#             "https://www.investopedia.com/terms/p/preferredstock.asp"
#           ],
#           "link_start_indexes": [
#             9,
#             163
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "7ac6e4e5eeba9e20b88bc793bc976238",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "60777c3699c2bc707660ac9f497eecfb",
#         "text": "An investor might want to know how many authorized shares a company has in order to analyze the potential for stock dilution. Dilution reduces a stockholder\u2019s share of ownership and voting power in a company and reduces a stock\u2019s earnings per share (EPS) following the issue of new stock. The larger the difference between the number of authorized shares\u00a0and the number of outstanding shares, the greater the potential for dilution.",
#         "metadata": {
#           "link_texts": [
#             "stock dilution",
#             "voting power",
#             "earnings per share"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/d/dilution.asp",
#             "https://www.investopedia.com/terms/v/votingright.asp",
#             "https://www.investopedia.com/terms/e/eps.asp"
#           ],
#           "link_start_indexes": [
#             110,
#             182,
#             230
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "7ac6e4e5eeba9e20b88bc793bc976238",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "f0daab5bca5db0d8d8fe64932c770d30",
#     "text": "Backorder: Definition, Causes, Example, Vs. Out-of-Stock",
#     "metadata": {
#       "category_depth": 0,
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "2a37f5ba64fc63355aa901b709e65094",
#     "text": "What Is the Difference Between Backorder and Out of Stock?",
#     "metadata": {
#       "category_depth": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "50f0354de5e99e347698333cae43da17",
#         "text": "A backorder and out-of-stock are similar. Whereas out-of-stock is an indicator that good is not available, a backorder often signifies that out-of-stock order may still be able to be ordered but is not available for immediate shipment. A company may keep a product as out-of-stock if it does not wish to further sell more units of that product. However, a backordered product is more likely to return due to a temporary delay in product availability.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "2a37f5ba64fc63355aa901b709e65094",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "b00fccf45303f0e78039b6c28d7f7c32",
#     "text": "Basic Materials Sector: Definition, Examples, and Stocks",
#     "metadata": {
#       "category_depth": 0,
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "8cef393211b3295a193d77cc4dceb761",
#     "text": "The Basic Materials Stock Sector",
#     "metadata": {
#       "category_depth": 2,
#       "emphasized_text_contents": [
#         "The Basic Materials Stock Sector"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "9adaf256c9946517d516ad2ff44bc00a",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "6574f9d81795dd04415b062970bb6abe",
#         "text": "For the purposes of stock categorization, the most common materials within the sector are mined products, such as metals and ore, and forestry products, or lumber. The stocks of certain chemical producers and energy sources also are included in the basic materials sector.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "8cef393211b3295a193d77cc4dceb761",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "d6c2ce4eb5195701c2c24ad6bf164480",
#         "text": "Containers and packaging are categorized as basic materials, whether they're made of glass, metal, or cardboard.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "8cef393211b3295a193d77cc4dceb761",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "5b0759ddebffa067ce5ab4c5e281fca8",
#     "text": "Basic Materials Stocks",
#     "metadata": {
#       "category_depth": 2,
#       "emphasized_text_contents": [
#         "Basic Materials Stocks"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "9b073a6c8794a8c156d651709a736e77",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "8b2a45a331b395aaaae8fc8bfe8001fa",
# ...
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "2d93ef3d80475d285ab12486f6ea75df",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "10dd546a8b09287eafc32d4570ed9e0d",
#     "text": "Stock Exchange Symbols",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "Stock Exchange Symbols"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "472fb29073127be21b75e6b13d5444a1",
#         "text": "U.S.-listed ADR securities will usually have a two-to-five character ticker symbol with the last character being the letter Y. The Y identifies the stock as an American depositary receipt. When investors buy or sell ADRs, they are trading in the U.S. market\u00a0and the trade will clear in U.S. dollars. Y stock listings are typically most common on over-the-counter markets, while ADRs trading large U.S. exchanges may or may not include the letter.",
#         "metadata": {
#           "link_texts": [
#             "trade will clear"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/p/post-trade-processing.asp"
#           ],
#           "link_start_indexes": [
#             266
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "10dd546a8b09287eafc32d4570ed9e0d",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "c890e112f7d0fd81f55b9390a7ba72bf",
#     "text": "Examples of Y Stock Listings",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "Examples of Y Stock Listings"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "c8d3186d8fd0963ee58a7c87efe4baf1",
#         "text": "Two examples of Y stock listings include Adidas AG and BNP Paribas S.A. Both stocks trade on the over-the-counter market. Adidas AG, a German sportswear company, trades with the symbol ADDYY. Financial services firm\u00a0BNP Paribas S.A.\u00a0trades with the symbol BNPQY.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "c890e112f7d0fd81f55b9390a7ba72bf",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "ee645a791333cb1d79d1e3ba70289752",
#     "text": "Yield on Stocks",
#     "metadata": {
#       "category_depth": 2,
#       "emphasized_text_contents": [
#         "Yield on Stocks"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "f9504e3f0f5aecdaa369e4dfc4ad58e8",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "57997d622235f586b938c416d074fc1e",
#         "text": "For stock-based investments, two types of yields are popularly used. When calculated based on the purchase price, the yield is called yield on cost (YOC) or cost yield and is calculated as:",
#         "metadata": {
#           "link_texts": [
#             "yield on cost"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/y/yield-on-cost.asp"
#           ],
#           "link_start_indexes": [
#             134
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "ee645a791333cb1d79d1e3ba70289752",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "576586712820615da59c30faea02f53e",
#         "text": "For example, if an investor realized a profit of $20 ($120 - $100) resulting from price rise, and also gained $2 from a dividend paid by the company. Therefore, the cost yield comes to ($20 + $2) / $100 = 0.22, or 22%.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "ee645a791333cb1d79d1e3ba70289752",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "8a96e9f987686757bb9d834000c513ca",
#         "text": "However, many investors may like to calculate the yield based on the current market price, instead of the purchase price. This yield is referred to as the current yield and is calculated as:",
#         "metadata": {
#           "link_texts": [
#             "current yield"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/c/currentyield.asp"
#           ],
#           "link_start_indexes": [
#             155
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "ee645a791333cb1d79d1e3ba70289752",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "674bdfa95d79b5ecde74256e6195fe1f",
#         "text": "For example, the current yield comes to ($20 + $2) / $120 = 0.1833, or 18.33%.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "ee645a791333cb1d79d1e3ba70289752",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "efcfc9e93ed9e0b65cf137f590d4770f",
#         "text": "When a company's stock price increases, the current yield goes down because of the inverse relationship between yield and stock price.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "ee645a791333cb1d79d1e3ba70289752",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "4a3b7d418507458f7e4be5af5200f737",
#     "text": "What Is Zacks Stock Screener?",
#     "metadata": {
#       "category_depth": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "1e18abb7166068e0efb88baca91b0052",
#         "text": "The Stock Screener is a paid product by Zacks Investment Research that allows an investor to sort and search for stocks according to desirable metrics, such as price changes, dividends, or return on investment. In keeping with their focus on earnings estimates, the Zacks Stock Screener also allows investors to sort stocks according to their Zacks Rank and changes to their earnings per share.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "4a3b7d418507458f7e4be5af5200f737",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "bd7644f55edf257dc1ceac4c8f894c0f",
#     "text": "How Much Does Zacks Stock Screener Cost?",
#     "metadata": {
#       "category_depth": 1,
#       "languages": [
#         "eng"
#       ],
#       "parent_id": "1d6f144c0ca8b86aac2de00ae1523abe",
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "432ac2eb2879a803286e8621d75586e6",
#         "text": "Zacks Premium Screens are available with a premium membership, priced at $249 per year. This product is also available for higher tiers, with prices ranging as high as $2995 per year.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "bd7644f55edf257dc1ceac4c8f894c0f",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "e9e247e5edfacc8f8ad74d525b84b813",
#     "text": "Zero-Dividend Preferred Stock: What it is, Pros and Cons",
#     "metadata": {
#       "category_depth": 0,
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "0fb5466c220c6674a95172765bc64e93",
#     "text": "What Is Zero-Dividend Preferred Stock?",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "What Is Zero-Dividend Preferred Stock?"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "0538965d6e5836b25a11eed8bd78c2f9",
#         "text": "A zero-dividend preferred stock\u00a0is a preferred share issued by a company that is not required to pay a dividend to its holder. The owner of a zero-dividend preferred share will earn income from capital appreciation and may receive a one-time payment at the end of the investment term.",
#         "metadata": {
#           "link_texts": [
#             "preferred stock",
#             "dividend",
#             "capital appreciation"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/p/preferredstock.asp",
#             "https://www.investopedia.com/terms/d/dividend.asp",
#             "https://www.investopedia.com/terms/c/capitalappreciation.asp"
#           ],
#           "link_start_indexes": [
#             16,
#             103,
#             194
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "0fb5466c220c6674a95172765bc64e93",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "c222ae3c08ab081f774ff45f0e5fa3ba",
#     "text": "Understanding Zero-Dividend Preferred Stock",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "Understanding Zero-Dividend Preferred Stock"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "14a4e433f2237f2de312162e2ec67d63",
#         "text": "When a company issues stock, they issue two types: preferred stock and common stock. Preferred stock has priority over common stock when it comes to dividends and asset distribution and is therefore seen as less risky. Preferred stock usually does not have voting rights, whereas common stock does.",
#         "metadata": {
#           "link_texts": [
#             "common stock",
#             "voting rights"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/c/commonstock.asp",
#             "https://www.investopedia.com/terms/v/votingright.asp"
#           ],
#           "link_start_indexes": [
#             71,
#             257
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "c222ae3c08ab081f774ff45f0e5fa3ba",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "0100343683f7307b7b353dd3224eb368",
#         "text": "Owners of zero-dividend preference shares will not receive a normal dividend but they will still maintain reimbursement priority over common shareholders in the event of a bankruptcy. In such an event, they will get a fixed sum that was agreed upon in advance.",
#         "metadata": {
#           "link_texts": [
#             "preference shares",
#             "common shareholders"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/p/preference-shares.asp",
#             "https://www.investopedia.com/terms/c/common_shareholder.asp"
#           ],
#           "link_start_indexes": [
#             24,
#             134
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "c222ae3c08ab081f774ff45f0e5fa3ba",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "0cdf8afd06c0b2776a9867b4a9818298",
#         "text": "Zero-dividend preferred stock is comparable in some ways to zero-coupon bonds, though they are regarded as lower tier than bonds. Still, they do have upper-tier preference compared with common shareholders if a bankruptcy occurs. This type of stock is usually backed by the issuer\u2019s assets and can be part of split capital investment trusts as a sort of share to produce fixed capital growth in a defined period.",
#         "metadata": {
#           "link_texts": [
#             "zero-coupon bonds"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/z/zero-couponbond.asp"
#           ],
#           "link_start_indexes": [
#             60
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "c222ae3c08ab081f774ff45f0e5fa3ba",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "15938d0cd88d7ea00dadcde7222d4843",
#     "text": "Why Zero-Dividend Preferred Stock Is Issued",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "Why Zero-Dividend Preferred Stock Is Issued"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "80980c719ac5760649eb10b48e79cac0",
#         "text": "Companies that are likely to issue zero-dividend preferred stock include investment trusts, particularly those that may face challenges getting long-term debt approved. Zero-dividend preferred stock usually comes with a specific time period.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "15938d0cd88d7ea00dadcde7222d4843",
#           "filetype": "text/html"
#         }
#       },
#       {
#         "type": "NarrativeText",
#         "element_id": "16974413dcc63218d22c6909e488fec6",
#         "text": "Issuing zero-dividend preferred stock is a way for an investment trust to raise capital that is easier than seeking a loan from a bank, and oftentimes lasts much longer than a bank would typically be willing to lend for. Zero-dividend preferred stock also comes with fewer restrictions than a bank would include in a loan. A zero-dividend preferred stock raises capital, holds no voting rights, and doesn't pay out a dividend. It's an extremely attractive option for a company to issue.",
#         "metadata": {
#           "link_texts": [
#             "capital"
#           ],
#           "link_urls": [
#             "https://www.investopedia.com/terms/c/capital.asp"
#           ],
#           "link_start_indexes": [
#             80
#           ],
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "15938d0cd88d7ea00dadcde7222d4843",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   },
#   {
#     "type": "Title",
#     "element_id": "21ccb9e86ab5c7866702bc66be0c82c6",
#     "text": "Advantages and Disadvantages of Zero-Dividend Preferred Stock",
#     "metadata": {
#       "category_depth": 1,
#       "emphasized_text_contents": [
#         "Advantages and Disadvantages of Zero-Dividend Preferred Stock"
#       ],
#       "emphasized_text_tags": [
#         "span"
#       ],
#       "languages": [
#         "eng"
#       ],
#       "filetype": "text/html"
#     },
#     "narratives": [
#       {
#         "type": "NarrativeText",
#         "element_id": "826d45a95660ea90a87b87ad171394de",
#         "text": "There are many advantages and disadvantages for an investor that come with a zero-dividend preferred stock.",
#         "metadata": {
#           "languages": [
#             "eng"
#           ],
#           "parent_id": "21ccb9e86ab5c7866702bc66be0c82c6",
#           "filetype": "text/html"
#         }
#       }
#     ]
#   }
# ]

# %%
# Step 1: Read the JSON data from the file
with open('all_cleaned_records.txt', 'r') as file:
    all_cleaned_jsons = json.load(file)

# Step 2: Initialize the Chroma client
client = chromadb.PersistentClient(path="chroma_tmp", settings=chromadb.Settings(allow_reset=True))
client.reset()

# Step 3: Create a collection
collection = client.create_collection(
    name="investopedia_articles_2",
    metadata={"hnsw:space": "cosine"}
)

# Step 4: Prepare elements for the collection
elements_list = []

# Iterate through the cleaned JSON objects and prepare the elements for the collection
for record in all_cleaned_jsons:
    # Add the metadata title first
    metadata = record.get('metadata')
    if metadata and metadata.get('text'):
        elements_list.append({
            "text": metadata['text'],
            "element_id": metadata['element_id'],
            "metadata": {"type": metadata['type'], "is_title": True, "element_id": metadata['element_id']}
        })

    # Add the titles and narratives within the data
    for item in record.get('data', []):
        if item.get('type') == 'Title' and item.get('text'):
            elements_list.append({
                "text": item['text'],
                "element_id": item['element_id'],
                "metadata": {"type": item['type'], "is_title": True, "element_id": item['element_id']}
            })
        if 'narratives' in item:
            for narrative in item['narratives']:
                elements_list.append({
                    "text": narrative['text'],
                    "element_id": narrative['element_id'],
                    "metadata": {"type": narrative['type'], "is_title": False, "parent_title_id": item['element_id']}
                })

# Step 5: Add elements to the collection
for element in elements_list:
    collection.add(
        documents=[element["text"]],
        ids=[element["element_id"]],
        metadatas=[element["metadata"]]
    )

# Step 6: Peek at the collection to ensure elements are added
results = collection.peek()
print(results["documents"])
